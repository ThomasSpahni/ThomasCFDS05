# %%
import numpy as np

from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram
#from sklearn.datasets import load_iris
from sklearn.cluster import AgglomerativeClustering

import pandas as pd
import numpy as np

# %%
df = pd.read_excel ('/Users/thomasspahni/CFDS05 Data/File 2019_22.xlsx')
print (df)
# Out:
#      Current Ratio  Quick Ratio  Cash Ratio  Debt-to-Equity   \
# 0         0.055797     0.043858    0.068605         0.869233
# 1         0.017800     0.013723    0.023794         0.000000
# 2         0.046244     0.010043    0.009654         0.871241
# 3         0.056051     0.054630    0.098214         0.872214
# 4         0.115928     0.111674    0.264508         0.847272
# ..             ...          ...         ...              ...
# 417       0.065097     0.057708    0.082364         0.870255
# 418       0.059420     0.046287    0.049805         0.870268
# 419       0.035965     0.035965    0.040538         0.864732
# 420       0.049925     0.024580    0.018539         0.869229
# 421       0.095874     0.067321    0.110573         0.873103
#
#      Debt to Total Assets  STD / Total Assets  LTD / Total Assets  \
# 0                0.085542            0.122619            0.064328
# 1                0.136140            0.089723            0.121401
# ...

# %%
data = pd.read_excel (r'/Users/thomasspahni/CFDS05 Data/File 2019_22.xlsx') 
df = pd.DataFrame(data)
print (df)
num_columns = len(df.columns)

pd.set_option("display.max_columns", num_columns)
df.head(422)
# Out:
#      Current Ratio  Quick Ratio  Cash Ratio  Debt-to-Equity   \
# 0         0.055797     0.043858    0.068605         0.869233
# 1         0.017800     0.013723    0.023794         0.000000
# 2         0.046244     0.010043    0.009654         0.871241
# 3         0.056051     0.054630    0.098214         0.872214
# 4         0.115928     0.111674    0.264508         0.847272
# ..             ...          ...         ...              ...
# 417       0.065097     0.057708    0.082364         0.870255
# 418       0.059420     0.046287    0.049805         0.870268
# 419       0.035965     0.035965    0.040538         0.864732
# 420       0.049925     0.024580    0.018539         0.869229
# 421       0.095874     0.067321    0.110573         0.873103
#
#      Debt to Total Assets  STD / Total Assets  LTD / Total Assets  \
# 0                0.085542            0.122619            0.064328
# 1                0.136140            0.089723            0.121401
# ...

# %%
def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack([model.children_, model.distances_,
                                      counts]).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)


#iris = load_iris()
X = df

# setting distance_threshold=0 ensures we compute the full tree.
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None)

model = model.fit(X)
plt.title('Hierarchical Clustering Dendrogram 2019')
# plot the top three levels of the dendrogram
plot_dendrogram(model, truncate_mode='level', p=3)
plt.xlabel("Number of points in node (or index of point if no parenthesis).")
plt.show()
